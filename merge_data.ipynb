# %%
import pandas as pd

# %%
file = "docs/YCDL.xlsx"

# %%
hba1c = pd.read_excel(file, sheet_name="HBa1C")

# %%
hba1c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229419 entries, 0 to 229418
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   TenBenhNhan         229419 non-null  object
#  1   SoVaoVien           229419 non-null  int64
#  2   NamSinh             229419 non-null  int64
#  3   GioiTinh            229419 non-null  object
#  4   TenDichVu           229419 non-null  object
#  5   KetQua              229419 non-null  object
#  6   NgayThucHien        229419 non-null  object
#  7   MaICD Bn nội trú    123564 non-null  object
#  8   MaICD BN ngoại trú  103999 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 15.8+ MB

# %%
df_hba1c = hba1c.drop(columns=["TenDichVu", "NgayThucHien"])
df_hba1c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229419 entries, 0 to 229418
# Data columns (total 7 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   TenBenhNhan         229419 non-null  object
#  1   SoVaoVien           229419 non-null  int64
#  2   NamSinh             229419 non-null  int64
#  3   GioiTinh            229419 non-null  object
#  4   KetQua              229419 non-null  object
#  5   MaICD Bn nội trú    123564 non-null  object
#  6   MaICD BN ngoại trú  103999 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 12.3+ MB

# %%
ldl = pd.read_excel(file, sheet_name="LDL")
